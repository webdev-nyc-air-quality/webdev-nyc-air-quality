# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as gpd

import json
import sys
import geojson

# %%
with open('VehicleIdling.json', 'r') as f:
    data = json.load(f)
df = pd.DataFrame(data)

print('Number of rows: ', len(df))
str(df.columns.tolist())
# Out:
# Number of rows:  20938
# "['Address Type', 'Agency', 'Agency Name', 'Borough', 'Bridge Highway Direction', 'Bridge Highway Name', 'Bridge Highway Segment', 'City', 'Closed Date', 'Community Board', 'Complaint Type', 'Created Date', 'Cross Street 1', 'Cross Street 2', 'Descriptor', 'Due Date', 'Facility Type', 'Incident Address', 'Incident Zip', 'Intersection Street 1', 'Intersection Street 2', 'Landmark', 'Latitude', 'Location', 'Location Type', 'Longitude', 'Park Borough', 'Park Facility Name', 'Resolution Action Updated Date', 'Resolution Description', 'Road Ramp', 'Status', 'Street Name', 'Taxi Company Borough', 'Taxi Pick Up Location', 'Unique Key', 'Vehicle Type', 'X Coordinate (State Plane)', 'Y Coordinate (State Plane)']"

# %%
df.head()
# Out:
#    Address Type Agency                             Agency Name        Borough  \
# 0       ADDRESS    DEP  Department of Environmental Protection      MANHATTAN
# 1       ADDRESS    DEP  Department of Environmental Protection  STATEN ISLAND
# 2       ADDRESS    DEP  Department of Environmental Protection         QUEENS
# 3  INTERSECTION    DEP  Department of Environmental Protection      MANHATTAN
# 4  INTERSECTION    DEP  Department of Environmental Protection       BROOKLYN
#
#   Bridge Highway Direction Bridge Highway Name Bridge Highway Segment  \
# 0
# 1
# 2
# 3
# 4
#
#             City             Closed Date   Community Board  \
# 0       NEW YORK  01/07/2010 03:45:00 PM      05 MANHATTAN
# 1  STATEN ISLAND  01/11/2010 05:45:00 PM  02 STATEN ISLAND
# 2  Rockaway Park  01/09/2010 05:15:00 PM         14 QUEENS
# 3       NEW YORK  01/30/2010 07:00:00 PM      02 MANHATTAN
# 4       BROOKLYN  01/29/2010 10:15:00 AM       08 BROOKLYN
#
#              ...              \
# 0            ...
# 1            ...
# 2            ...
# 3            ...
# 4            ...
#
#                               Resolution Description Road Ramp  Status  \
# 0  The Department of Environmental Protection did...            Closed
# 1  The Department of Environmental Protection did...            Closed
# 2  The Department of Environmental Protection did...            Closed
# 3  The Department of Environmental Protection did...            Closed
# 4  The Department of Environmental Protection did...            Closed
#
#          Street Name Taxi Company Borough Taxi Pick Up Location Unique Key  \
# 0   WEST   47 STREET                                              15656648
# 1   ROCKVILLE AVENUE                                              15674887
# 2  BEACH  100 STREET                                              15675126
# 3                                                                 15831650
# 4                                                                 15831651
#
#   Vehicle Type  X Coordinate (State Plane) Y Coordinate (State Plane)
# 0                                  989,909                    215,099
# 1                                  938,560                    156,291
# 2                                1,033,664                    152,620
# 3                                  986,121                    205,580
# 4                                1,004,308                    185,447
#
# [5 rows x 39 columns]

# %%
df['Latitude'] = df['Latitude'].astype(float)
df['Longitude'] = df['Longitude'].astype(float)

# %%
useful_cols = ['Cross Street 1', 'Cross Street 2', 'Incident Zip', 'City', 'X Coordinate (State Plane)', 'Y Coordinate (State Plane)', 'Latitude', 'Longitude']
df_sub = df[useful_cols]
df_sub.head()
# Out:
#   Cross Street 1          Cross Street 2  Incident Zip           City  \
# 0       5 AVENUE  AVENUE OF THE AMERICAS         10036       NEW YORK
# 1    PLYMOUTH RD          BOWLING GRN PL         10314  STATEN ISLAND
# 2   NYCTA SUBWAY        BEACH CHANNEL DR         11694  Rockaway Park
# 3         E 8 ST               MERCER ST         10003       NEW YORK
# 4        DEAN ST           ROCHESTER AVE         11233       BROOKLYN
#
#   X Coordinate (State Plane) Y Coordinate (State Plane)   Latitude  Longitude
# 0                    989,909                    215,099  40.757072 -73.979574
# 1                    938,560                    156,291  40.595541 -74.164521
# 2                  1,033,664                    152,620  40.585445 -73.822096
# 3                    986,121                    205,580  40.730946 -73.993249
# 4                  1,004,308                    185,447  40.675663 -73.927688

# %%
df_geo = df_sub.dropna(subset=['Latitude', 'Longitude'], axis=0, inplace=False)
print(len(df_geo))
# Out:
# 20938

# %%
df_geo['City'].value_counts()
# Out:
# NEW YORK               7571
# BROOKLYN               7003
# BRONX                  1357
# STATEN ISLAND           881
# College Point           565
# Astoria                 336
# Cambria Heights         261
# Forest Hills            240
# Flushing                220
# Jamaica                 214
# Ridgewood               185
# Long Island City        178
# Woodside                119
# Sunnyside                80
# Jackson Heights          80
# Fresh Meadows            73
# Ozone Park               71
# Maspeth                  68
# Corona                   67
# East Elmhurst            66
# FOREST HILLS             65
# South Ozone Park         62
# Bayside                  60
# Rego Park                59
# Middle Village           58
# Elmhurst                 55
# Queens Village           54
# Far Rockaway             52
# Whitestone               52
# Saint Albans             49
#                        ...
# RICHMOND HILL             8
# CAMBRIA HEIGHTS           8
# JACKSON HEIGHTS           8
# Floral Park               8
# CORONA                    7
# QUEENS VILLAGE            7
# SOUTH RICHMOND HILL       7
# MIDDLE VILLAGE            6
# SPRINGFIELD GARDENS       6
# ELMHURST                  5
# LITTLE NECK               5
# Arverne                   5
# REGO PARK                 4
# ARVERNE                   4
# BAYSIDE                   4
# BELLEROSE                 4
# SOUTH OZONE PARK          4
# SUNNYSIDE                 3
# KEW GARDENS               3
# SAINT ALBANS              3
# ROCKAWAY PARK             3
# OZONE PARK                3
# MASPETH                   3
# QUEENS                    3
# HOWARD BEACH              2
# FAR ROCKAWAY              2
# ROSEDALE                  2
# New Hyde Park             1
# GLEN OAKS                 1
# OAKLAND GARDENS           1
# Name: City, Length: 83, dtype: int64

# %%
def df_to_geojson(df, props, lat='Latitude', lng='Longitude'):
    geojson = {'type':'FeatureCollection', 'features':[]}
    
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}
        feature['geometry']['coordinates'] = [row[lng], row[lat]]
        
        for prop in props:
            feature['properties'][prop] = row[prop]
            
        geojson['features'].append(feature)
    return geojson

# %%
useful_cols = ['Cross Street 1', 'Cross Street 2', 'City']
geojson_dict = df_to_geojson(df_geo, props=useful_cols)
geojson_str = json.dumps(geojson_dict, indent=2)

# %%
output_filename = 'VehicleIdling.js'
with open(output_filename, 'w') as output_file:
    output_file.write('var vehicleIdling = {};'.format(geojson_str))
